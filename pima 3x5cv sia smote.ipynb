# %% [markdown]
# <a href="https://colab.research.google.com/github/heroza/Keel/blob/main/pima%203x5cv%20sia%20smote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, roc_auc_score
from sklearn.model_selection import train_test_split

# load breast cancer dataset
breast_cancer = datasets.load_breast_cancer()
X = breast_cancer.data
y = breast_cancer.target

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# define SVM classifier and parameter grid
svc = svm.SVC(kernel='rbf', probability=True, class_weight='balanced')
param_grid = {'C': [0.1, 1, 10, 100, 1000], 'gamma': [0.01, 0.1, 1, 10, 100]}

# define scoring metrics
scorers = {
    'f1_score': make_scorer(f1_score, average='macro'),
    'roc_auc_score': make_scorer(roc_auc_score),
    'g_mean': make_scorer(balanced_accuracy_score)
}

# use GridSearchCV to search for best parameter values
grid_search = GridSearchCV(svc, param_grid=param_grid, scoring=scorers, refit='f1_score', cv=5)
grid_search.fit(X_train, y_train)

# print best parameter values and corresponding scores for each metric
print("Best parameters found:", grid_search.best_params_)
print("Best F1 score found:", grid_search.best_score_)
print("Best ROC AUC score found:", grid_search.cv_results_['mean_test_roc_auc_score'][grid_search.best_index_])
print("Best G-Mean score found:", grid_search.cv_results_['mean_test_g_mean'][grid_search.best_index_])
# Out:
# Best parameters found: {'C': 1, 'gamma': 0.01}
# Best F1 score found: 0.39917131326100763
# Best ROC AUC score found: 0.5067816091954023
# Best G-Mean score found: 0.5067816091954023

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, f1_score, roc_auc_score, balanced_accuracy_score
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
X = iris.data
y = iris.target

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# define SVM classifier and parameter grid
svc = svm.SVC(kernel='rbf', probability=True, class_weight='balanced')
param_grid = {'C': [0.1, 1, 10, 100, 1000], 'gamma': [0.01, 0.1, 1, 10, 100]}

# define scoring metrics
scorers = {
    'f1_score': make_scorer(f1_score, average='macro'),
    'roc_auc_score': make_scorer(roc_auc_score),
    'g_mean': make_scorer(balanced_accuracy_score)
}

# use GridSearchCV to search for best parameter values
grid_search = GridSearchCV(svc, param_grid=param_grid, scoring=scorers, refit='f1_score', cv=5)
grid_search.fit(X_train, y_train)

# print best parameter values and corresponding scores for each metric
print("Best parameters found:", grid_search.best_params_)
print("Best F1 score found:", grid_search.best_score_)
print("Best ROC AUC score found:", grid_search.cv_results_['mean_test_roc_auc_score'][grid_search.best_index_])
print("Best G-Mean score found:", grid_search.cv_results_['mean_test_g_mean'][grid_search.best_index_])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import myfunction as fu
import numpy as np
import pandas as pd
from typing_extensions import Counter
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn import svm
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split, StratifiedKFold
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %%
df = pd.read_csv('pima.dat', header=None)

# %%
df.head()
# Out:
#    0    1   2   3    4     5      6   7         8
# 0  6  148  72  35    0  33.6  0.627  50  positive
# 1  1   85  66  29    0  26.6  0.351  31  negative
# 2  8  183  64   0    0  23.3  0.672  32  positive
# 3  1   89  66  23   94  28.1  0.167  21  negative
# 4  0  137  40  35  168  43.1  2.288  33  positive

# %%
num_features=8

le = LabelEncoder()
X = df.loc[:, df.columns[0:num_features]].to_numpy()

scaler = MinMaxScaler()
X = scaler.fit_transform(X)

y = df.loc[:, df.columns[-1]].to_numpy()
y = le.fit_transform(y)
# y_train = y_train.reshape(-1)
print(X.shape)
print(Counter(y))
# Out:
# (768, 8)
# Counter({0: 500, 1: 268})

# %%
thresholds = [0.02, 0.05, 0.1, 0.3, 0.5]
ks = [3,5,7,9]
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
num_iteration=3
for k in ks:
  for threshold in thresholds:
    scores_cv_knn = []
    scores_cv_svc = []
    scores_cv_rf = []
    
    for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
      # print(f"Fold {fold+1}")
      X_train, X_test = X[train_index], X[test_index]
      y_train, y_test = y[train_index], y[test_index]
      # scores_all_iter_knn = []
      # scores_all_iter_svc = []
      # scores_all_iter_rf = []
      scores_all_iter = []
      for i in range(num_iteration):
        # random oversampling
        # oversample = RandomOverSampler(sampling_strategy='minority')
        # X_train_resampled, y_train_resampled = oversample.fit_resample(X, y)

        # sia smote
        sia_model = fu.train_siamese_dense(X_train, y_train, X_test, y_test, num_classes=2, num_features=num_features, epochs_siamese=100, batch_size=16)
        X_train_resampled, y_train_resampled = fu.sia_smote_balance_dense(X_train, y_train, sia_model, threshold, maxdist_from_base=0.5, k = k)

        score_clf = fu.train_and_get_score(X_train_resampled, y_train_resampled, X_test, y_test)
        # scores_all_iter_knn.append(score_knn)
        # scores_all_iter_svc.append(score_svc)
        # scores_all_iter_rf.append(score_rf)
        scores_all_iter.append(score_clf)
      # finish all iter, count mean
      mean_score = fu.mean_score(scores_all_iter)
      # print(f"Score_clf in fold:{fold}:", mean_score)
      scores_cv_knn.append(mean_score[0])
      scores_cv_svc.append(mean_score[1])
      scores_cv_rf.append(mean_score[2])

    print(f'k={k} and threshold={threshold}')
    print('printing score knn')
    fu.print_score(scores_cv_knn)
    print('printing score svc')
    fu.print_score(scores_cv_svc)
    print('printing score rf')
    fu.print_score(scores_cv_rf)
# Out:
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2563
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25628432631492615, Train Accuracy = 0.8051643192488263 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2482
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.24819093942642212, Train Accuracy = 0.82981220657277 Test Accuracy = 0.6132075471698113
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2904
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2903984487056732, Train Accuracy = 0.818075117370892 Test Accuracy = 0.6132075471698113
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2526
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.25259679555892944, Train Accuracy = 0.7723004694835681 Test Accuracy = 0.589622641509434
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2662
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2661569118499756, Train Accuracy = 0.7793427230046949 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2618
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2618236243724823, Train Accuracy = 0.7816901408450704 Test Accuracy = 0.5801886792452831
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2860
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.28599169850349426, Train Accuracy = 0.8133802816901409 Test Accuracy = 0.5518867924528302
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2895
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.28952324390411377, Train Accuracy = 0.82981220657277 Test Accuracy = 0.5235849056603774
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2662
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.266223281621933, Train Accuracy = 0.8110328638497653 Test Accuracy = 0.5801886792452831
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2396
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.23961560428142548, Train Accuracy = 0.7978971962616822 Test Accuracy = 0.6057692307692307
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2753
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2753121256828308, Train Accuracy = 0.8037383177570093 Test Accuracy = 0.5384615384615384
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2634
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.26341837644577026, Train Accuracy = 0.7920560747663551 Test Accuracy = 0.5913461538461539
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2544
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.25438717007637024, Train Accuracy = 0.8002336448598131 Test Accuracy = 0.6009615384615384
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2502
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.25016123056411743, Train Accuracy = 0.7920560747663551 Test Accuracy = 0.5961538461538461
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2651
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2650890052318573, Train Accuracy = 0.7897196261682243 Test Accuracy = 0.5721153846153846
# 6/6 [==============================] - 0s 2ms/step
# k=3 and threshold=0.02
# printing score knn
# bal_acc_arr: mean=71.004 std=2.586
# G_Mean_arr: mean=70.899 std=2.621
# F_Measure_arr: mean=63.129 std=2.919
# Auc_arr: mean=71.004 std=2.586
# Precision_arr: mean=56.864 std=3.262
# Sensitivity_arr: mean=71.274 std=3.692
# Specificity_arr: mean=70.733 std=3.623
# Acc_arr: mean=70.918 std=2.692
# printing score svc
# bal_acc_arr: mean=70.666 std=2.950
# G_Mean_arr: mean=70.568 std=2.980
# F_Measure_arr: mean=62.863 std=3.367
# Auc_arr: mean=70.666 std=2.950
# Precision_arr: mean=56.554 std=3.954
# Sensitivity_arr: mean=71.132 std=2.906
# Specificity_arr: mean=70.200 std=3.781
# Acc_arr: mean=70.524 std=3.137
# printing score rf
# bal_acc_arr: mean=70.983 std=2.914
# G_Mean_arr: mean=70.908 std=2.969
# F_Measure_arr: mean=63.197 std=3.337
# Auc_arr: mean=70.983 std=2.914
# Precision_arr: mean=56.689 std=3.657
# Sensitivity_arr: mean=71.633 std=2.840
# Specificity_arr: mean=70.333 std=3.300
# Acc_arr: mean=70.786 std=2.999
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2733
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2733345329761505, Train Accuracy = 0.7992957746478874 Test Accuracy = 0.5754716981132075
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2411
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.24105054140090942, Train Accuracy = 0.7816901408450704 Test Accuracy = 0.6226415094339622
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2679
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.26789382100105286, Train Accuracy = 0.8309859154929577 Test Accuracy = 0.6084905660377359
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2576
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.25761038064956665, Train Accuracy = 0.8051643192488263 Test Accuracy = 0.6084905660377359
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2679
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.267867773771286, Train Accuracy = 0.7863849765258216 Test Accuracy = 0.5943396226415094
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2738
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.27382808923721313, Train Accuracy = 0.7981220657276995 Test Accuracy = 0.5471698113207547
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2832
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.283246785402298, Train Accuracy = 0.8415492957746479 Test Accuracy = 0.5330188679245284
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3178
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.31782346963882446, Train Accuracy = 0.7922535211267606 Test Accuracy = 0.5235849056603774
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2754
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.27541348338127136, Train Accuracy = 0.8368544600938967 Test Accuracy = 0.5754716981132075
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2598
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2598496675491333, Train Accuracy = 0.764018691588785 Test Accuracy = 0.5865384615384616
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2611
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2610512971878052, Train Accuracy = 0.7675233644859814 Test Accuracy = 0.5913461538461539
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2437
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.24371348321437836, Train Accuracy = 0.7990654205607477 Test Accuracy = 0.6057692307692307
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2432
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.24322615563869476, Train Accuracy = 0.8154205607476636 Test Accuracy = 0.5721153846153846
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2720
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2719937264919281, Train Accuracy = 0.8271028037383178 Test Accuracy = 0.5625
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2705
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.27046191692352295, Train Accuracy = 0.8434579439252337 Test Accuracy = 0.6009615384615384
# 6/6 [==============================] - 0s 2ms/step
# k=3 and threshold=0.05
# printing score knn
# bal_acc_arr: mean=71.418 std=2.263
# G_Mean_arr: mean=71.326 std=2.341
# F_Measure_arr: mean=63.767 std=2.434
# Auc_arr: mean=71.418 std=2.263
# Precision_arr: mean=57.014 std=3.413
# Sensitivity_arr: mean=72.637 std=0.748
# Specificity_arr: mean=70.200 std=3.896
# Acc_arr: mean=71.048 std=2.756
# printing score svc
# bal_acc_arr: mean=71.784 std=2.922
# G_Mean_arr: mean=71.694 std=2.983
# F_Measure_arr: mean=64.213 std=3.281
# Auc_arr: mean=71.784 std=2.922
# Precision_arr: mean=57.176 std=3.950
# Sensitivity_arr: mean=73.501 std=2.101
# Specificity_arr: mean=70.067 std=3.884
# Acc_arr: mean=71.262 std=3.208
# printing score rf
# bal_acc_arr: mean=71.338 std=2.487
# G_Mean_arr: mean=71.261 std=2.520
# F_Measure_arr: mean=63.546 std=2.903
# Auc_arr: mean=71.338 std=2.487
# Precision_arr: mean=57.007 std=3.054
# Sensitivity_arr: mean=72.010 std=3.197
# Specificity_arr: mean=70.667 std=2.741
# Acc_arr: mean=71.134 std=2.453
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2771
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2770587205886841, Train Accuracy = 0.8251173708920188 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2732
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.27322304248809814, Train Accuracy = 0.8145539906103286 Test Accuracy = 0.5707547169811321
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3042
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.30418476462364197, Train Accuracy = 0.7969483568075117 Test Accuracy = 0.589622641509434
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2689
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2688828110694885, Train Accuracy = 0.8039906103286385 Test Accuracy = 0.6132075471698113
# 6/6 [==============================] - 0s 5ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2754
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.27543407678604126, Train Accuracy = 0.8110328638497653 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2666
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2666013836860657, Train Accuracy = 0.8075117370892019 Test Accuracy = 0.5801886792452831
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2838
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.28375130891799927, Train Accuracy = 0.8204225352112676 Test Accuracy = 0.5707547169811321
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3012
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.30116668343544006, Train Accuracy = 0.8169014084507042 Test Accuracy = 0.5330188679245284
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2989
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.29885029792785645, Train Accuracy = 0.8368544600938967 Test Accuracy = 0.5047169811320755
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2573
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2573124170303345, Train Accuracy = 0.7838785046728972 Test Accuracy = 0.6298076923076923
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2529
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25293999910354614, Train Accuracy = 0.8282710280373832 Test Accuracy = 0.6394230769230769
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2489
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2489030957221985, Train Accuracy = 0.8014018691588785 Test Accuracy = 0.6009615384615384
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2859
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.28589555621147156, Train Accuracy = 0.8154205607476636 Test Accuracy = 0.5288461538461539
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2707
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2706671953201294, Train Accuracy = 0.802570093457944 Test Accuracy = 0.5673076923076923
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2712
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2712276577949524, Train Accuracy = 0.8095794392523364 Test Accuracy = 0.5480769230769231
# 6/6 [==============================] - 0s 3ms/step
# k=3 and threshold=0.1
# printing score knn
# bal_acc_arr: mean=70.481 std=2.409
# G_Mean_arr: mean=70.386 std=2.469
# F_Measure_arr: mean=62.683 std=2.680
# Auc_arr: mean=70.481 std=2.409
# Precision_arr: mean=55.805 std=3.289
# Sensitivity_arr: mean=71.761 std=1.733
# Specificity_arr: mean=69.200 std=3.351
# Acc_arr: mean=70.091 std=2.679
# printing score svc
# bal_acc_arr: mean=70.125 std=2.918
# G_Mean_arr: mean=70.007 std=2.957
# F_Measure_arr: mean=62.357 std=3.142
# Auc_arr: mean=70.125 std=2.918
# Precision_arr: mean=55.513 std=4.039
# Sensitivity_arr: mean=71.516 std=2.494
# Specificity_arr: mean=68.733 std=4.519
# Acc_arr: mean=69.700 std=3.335
# printing score rf
# bal_acc_arr: mean=71.193 std=2.637
# G_Mean_arr: mean=71.068 std=2.643
# F_Measure_arr: mean=63.569 std=2.911
# Auc_arr: mean=71.193 std=2.637
# Precision_arr: mean=56.345 std=3.434
# Sensitivity_arr: mean=73.252 std=2.761
# Specificity_arr: mean=69.133 std=3.600
# Acc_arr: mean=70.569 std=2.844
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2396
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.23955518007278442, Train Accuracy = 0.8016431924882629 Test Accuracy = 0.6462264150943396
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2751
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.27505627274513245, Train Accuracy = 0.7687793427230047 Test Accuracy = 0.5471698113207547
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2456
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2455691546201706, Train Accuracy = 0.7946009389671361 Test Accuracy = 0.6273584905660378
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2590
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2590481638908386, Train Accuracy = 0.7769953051643192 Test Accuracy = 0.5754716981132075
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2730
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2730022072792053, Train Accuracy = 0.8016431924882629 Test Accuracy = 0.5990566037735849
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2565
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25651735067367554, Train Accuracy = 0.7969483568075117 Test Accuracy = 0.589622641509434
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3221
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.32209375500679016, Train Accuracy = 0.8368544600938967 Test Accuracy = 0.5377358490566038
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2685
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.26851600408554077, Train Accuracy = 0.8309859154929577 Test Accuracy = 0.6037735849056604
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2947
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2946655750274658, Train Accuracy = 0.812206572769953 Test Accuracy = 0.5235849056603774
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2601
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.26009681820869446, Train Accuracy = 0.802570093457944 Test Accuracy = 0.5576923076923077
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2568
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25679531693458557, Train Accuracy = 0.7932242990654206 Test Accuracy = 0.5721153846153846
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2506
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2506234049797058, Train Accuracy = 0.7885514018691588 Test Accuracy = 0.625
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2838
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2838374972343445, Train Accuracy = 0.7873831775700935 Test Accuracy = 0.5817307692307693
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2692
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.26920655369758606, Train Accuracy = 0.8282710280373832 Test Accuracy = 0.5576923076923077
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2498
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.249821737408638, Train Accuracy = 0.8457943925233645 Test Accuracy = 0.6057692307692307
# 6/6 [==============================] - 0s 2ms/step
# k=3 and threshold=0.3
# printing score knn
# bal_acc_arr: mean=71.211 std=2.389
# G_Mean_arr: mean=71.077 std=2.427
# F_Measure_arr: mean=63.586 std=2.586
# Auc_arr: mean=71.211 std=2.389
# Precision_arr: mean=56.052 std=3.231
# Sensitivity_arr: mean=73.755 std=3.278
# Specificity_arr: mean=68.667 std=4.000
# Acc_arr: mean=70.440 std=2.688
# printing score svc
# bal_acc_arr: mean=72.828 std=2.274
# G_Mean_arr: mean=72.687 std=2.318
# F_Measure_arr: mean=65.403 std=2.529
# Auc_arr: mean=72.828 std=2.274
# Precision_arr: mean=58.144 std=3.223
# Sensitivity_arr: mean=75.122 std=3.107
# Specificity_arr: mean=70.533 std=3.804
# Acc_arr: mean=72.131 std=2.566
# printing score rf
# bal_acc_arr: mean=71.015 std=2.133
# G_Mean_arr: mean=70.866 std=2.198
# F_Measure_arr: mean=63.331 std=2.281
# Auc_arr: mean=71.015 std=2.133
# Precision_arr: mean=56.308 std=3.145
# Sensitivity_arr: mean=72.763 std=2.680
# Specificity_arr: mean=69.267 std=3.929
# Acc_arr: mean=70.485 std=2.530
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2680
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.2680438458919525, Train Accuracy = 0.7969483568075117 Test Accuracy = 0.5943396226415094
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2593
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25926879048347473, Train Accuracy = 0.7816901408450704 Test Accuracy = 0.6084905660377359
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2523
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25234538316726685, Train Accuracy = 0.7652582159624414 Test Accuracy = 0.589622641509434
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2486
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.24857816100120544, Train Accuracy = 0.8145539906103286 Test Accuracy = 0.6084905660377359
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2678
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2677902281284332, Train Accuracy = 0.7910798122065728 Test Accuracy = 0.5754716981132075
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2399
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2398669421672821, Train Accuracy = 0.812206572769953 Test Accuracy = 0.6273584905660378
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2767
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.27667236328125, Train Accuracy = 0.8169014084507042 Test Accuracy = 0.5188679245283019
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2735
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.273497998714447, Train Accuracy = 0.8345070422535211 Test Accuracy = 0.5613207547169812
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3055
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.3055284023284912, Train Accuracy = 0.82981220657277 Test Accuracy = 0.5707547169811321
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2601
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.26006758213043213, Train Accuracy = 0.8271028037383178 Test Accuracy = 0.5625
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2578
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25781017541885376, Train Accuracy = 0.7757009345794392 Test Accuracy = 0.6057692307692307
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2302
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.23022738099098206, Train Accuracy = 0.7827102803738317 Test Accuracy = 0.6394230769230769
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3083
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.30826184153556824, Train Accuracy = 0.7955607476635514 Test Accuracy = 0.5336538461538461
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2593
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25928497314453125, Train Accuracy = 0.8130841121495327 Test Accuracy = 0.625
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2556
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2556416392326355, Train Accuracy = 0.8142523364485982 Test Accuracy = 0.6105769230769231
# 6/6 [==============================] - 0s 3ms/step
# k=3 and threshold=0.5
# printing score knn
# bal_acc_arr: mean=71.383 std=2.525
# G_Mean_arr: mean=71.252 std=2.542
# F_Measure_arr: mean=63.750 std=2.969
# Auc_arr: mean=71.383 std=2.525
# Precision_arr: mean=56.553 std=3.307
# Sensitivity_arr: mean=73.366 std=3.413
# Specificity_arr: mean=69.400 std=3.473
# Acc_arr: mean=70.783 std=2.643
# printing score svc
# bal_acc_arr: mean=70.294 std=2.571
# G_Mean_arr: mean=70.144 std=2.619
# F_Measure_arr: mean=62.514 std=2.788
# Auc_arr: mean=70.294 std=2.571
# Precision_arr: mean=55.229 std=3.531
# Sensitivity_arr: mean=72.388 std=2.675
# Specificity_arr: mean=68.200 std=4.075
# Acc_arr: mean=69.657 std=2.922
# printing score rf
# bal_acc_arr: mean=70.528 std=2.572
# G_Mean_arr: mean=70.404 std=2.653
# F_Measure_arr: mean=62.738 std=2.767
# Auc_arr: mean=70.528 std=2.572
# Precision_arr: mean=56.139 std=3.969
# Sensitivity_arr: mean=71.523 std=2.839
# Specificity_arr: mean=69.533 std=4.893
# Acc_arr: mean=70.221 std=3.146
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3390
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.33902305364608765, Train Accuracy = 0.7934272300469484 Test Accuracy = 0.5518867924528302
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2756
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.275560200214386, Train Accuracy = 0.8450704225352113 Test Accuracy = 0.589622641509434
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2859
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2859378159046173, Train Accuracy = 0.8427230046948356 Test Accuracy = 0.589622641509434
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2540
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25403735041618347, Train Accuracy = 0.795774647887324 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2819
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.28194788098335266, Train Accuracy = 0.7922535211267606 Test Accuracy = 0.5801886792452831
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2612
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2611504793167114, Train Accuracy = 0.8169014084507042 Test Accuracy = 0.5707547169811321
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3330
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.33302244544029236, Train Accuracy = 0.8321596244131455 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2688
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.26878464221954346, Train Accuracy = 0.7734741784037559 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2793
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2793232500553131, Train Accuracy = 0.8251173708920188 Test Accuracy = 0.5660377358490566
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2515
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2514895796775818, Train Accuracy = 0.7897196261682243 Test Accuracy = 0.5625
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# ...
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.279094934463501, Train Accuracy = 0.7990654205607477 Test Accuracy = 0.5769230769230769
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2753
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2753252685070038, Train Accuracy = 0.8399532710280374 Test Accuracy = 0.5432692307692307
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2952
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.2952166795730591, Train Accuracy = 0.7908878504672897 Test Accuracy = 0.5625
# 6/6 [==============================] - 0s 3ms/step
# k=5 and threshold=0.3
# printing score knn
# bal_acc_arr: mean=71.899 std=2.972
# G_Mean_arr: mean=71.785 std=3.007
# F_Measure_arr: mean=64.358 std=3.328
# Auc_arr: mean=71.899 std=2.972
# Precision_arr: mean=57.131 std=4.023
# Sensitivity_arr: mean=73.997 std=3.052
# Specificity_arr: mean=69.800 std=4.097
# Acc_arr: mean=71.264 std=3.216
# printing score svc
# bal_acc_arr: mean=71.140 std=2.206
# G_Mean_arr: mean=70.946 std=2.246
# F_Measure_arr: mean=63.538 std=2.359
# Auc_arr: mean=71.140 std=2.206
# Precision_arr: mean=55.923 std=3.066
# Sensitivity_arr: mean=74.014 std=3.544
# Specificity_arr: mean=68.267 std=4.019
# Acc_arr: mean=70.267 std=2.508
# printing score rf
# bal_acc_arr: mean=71.779 std=2.829
# G_Mean_arr: mean=71.651 std=2.888
# F_Measure_arr: mean=64.281 std=3.037
# Auc_arr: mean=71.779 std=2.829
# Precision_arr: mean=56.628 std=3.769
# Sensitivity_arr: mean=74.624 std=2.739
# Specificity_arr: mean=68.933 std=4.363
# Acc_arr: mean=70.914 std=3.210
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2839
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.28393784165382385, Train Accuracy = 0.8063380281690141 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2872
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2872002124786377, Train Accuracy = 0.8051643192488263 Test Accuracy = 0.5707547169811321
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2593
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25926104187965393, Train Accuracy = 0.8169014084507042 Test Accuracy = 0.5754716981132075
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2558
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2558293342590332, Train Accuracy = 0.8016431924882629 Test Accuracy = 0.5566037735849056
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2473
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.2472875863313675, Train Accuracy = 0.7875586854460094 Test Accuracy = 0.589622641509434
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2700
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.26997458934783936, Train Accuracy = 0.7852112676056338 Test Accuracy = 0.5471698113207547
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2958
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.29584869742393494, Train Accuracy = 0.8309859154929577 Test Accuracy = 0.5471698113207547
# 6/6 [==============================] - 0s 5ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2983
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.29829326272010803, Train Accuracy = 0.8192488262910798 Test Accuracy = 0.5283018867924528
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2860
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.28598806262016296, Train Accuracy = 0.8485915492957746 Test Accuracy = 0.5707547169811321
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2737
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2736520767211914, Train Accuracy = 0.7815420560747663 Test Accuracy = 0.5865384615384616
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2434
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.24344666302204132, Train Accuracy = 0.7850467289719626 Test Accuracy = 0.6201923076923077
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2566
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.256557822227478, Train Accuracy = 0.7897196261682243 Test Accuracy = 0.6394230769230769
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2791
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2791081368923187, Train Accuracy = 0.8119158878504673 Test Accuracy = 0.5480769230769231
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2819
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2819052040576935, Train Accuracy = 0.8586448598130841 Test Accuracy = 0.5336538461538461
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2696
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.26961296796798706, Train Accuracy = 0.8411214953271028 Test Accuracy = 0.5528846153846154
# 6/6 [==============================] - 0s 4ms/step
# k=5 and threshold=0.5
# printing score knn
# bal_acc_arr: mean=71.912 std=2.293
# G_Mean_arr: mean=71.762 std=2.360
# F_Measure_arr: mean=64.352 std=2.525
# Auc_arr: mean=71.912 std=2.293
# Precision_arr: mean=56.658 std=3.069
# Sensitivity_arr: mean=74.757 std=2.340
# Specificity_arr: mean=69.067 std=3.395
# Acc_arr: mean=71.047 std=2.550
# printing score svc
# bal_acc_arr: mean=70.606 std=2.084
# G_Mean_arr: mean=70.476 std=2.133
# F_Measure_arr: mean=62.840 std=2.305
# Auc_arr: mean=70.606 std=2.084
# Precision_arr: mean=55.986 std=3.675
# Sensitivity_arr: mean=72.013 std=1.485
# Specificity_arr: mean=69.200 std=4.167
# Acc_arr: mean=70.178 std=2.670
# printing score rf
# bal_acc_arr: mean=71.098 std=2.568
# G_Mean_arr: mean=70.945 std=2.684
# F_Measure_arr: mean=63.500 std=2.735
# Auc_arr: mean=71.098 std=2.568
# Precision_arr: mean=56.291 std=3.967
# Sensitivity_arr: mean=73.263 std=1.296
# Specificity_arr: mean=68.933 std=4.673
# Acc_arr: mean=70.441 std=3.184
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2509
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.250884085893631, Train Accuracy = 0.789906103286385 Test Accuracy = 0.5990566037735849
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2526
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.25260403752326965, Train Accuracy = 0.7793427230046949 Test Accuracy = 0.5801886792452831
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3001
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.3001486361026764, Train Accuracy = 0.8356807511737089 Test Accuracy = 0.6037735849056604
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2347
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.23474270105361938, Train Accuracy = 0.8251173708920188 Test Accuracy = 0.6415094339622641
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2616
# predict train
# 27/27 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2616235315799713, Train Accuracy = 0.8309859154929577 Test Accuracy = 0.5566037735849056
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2692
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.26918357610702515, Train Accuracy = 0.8051643192488263 Test Accuracy = 0.5849056603773585
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3306
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.3305710554122925, Train Accuracy = 0.8004694835680751 Test Accuracy = 0.5330188679245284
# 6/6 [==============================] - 0s 5ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3223
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 2ms/step
# compute val acc
# Loss = 0.3222574293613434, Train Accuracy = 0.846244131455399 Test Accuracy = 0.5283018867924528
# 6/6 [==============================] - 0s 3ms/step
# creating pairs
# Counter({1.0: 426, 0.0: 426})
# Counter({1.0: 106, 0.0: 106})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2949
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2948583662509918, Train Accuracy = 0.8192488262910798 Test Accuracy = 0.5377358490566038
# 6/6 [==============================] - 0s 4ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...
# evaluate
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2555
# predict train
# 27/27 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 7/7 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2554892897605896, Train Accuracy = 0.8107476635514018 Test Accuracy = 0.6201923076923077
# 6/6 [==============================] - 0s 2ms/step
# creating pairs
# Counter({1.0: 428, 0.0: 428})
# Counter({1.0: 104, 0.0: 104})
# init base network
# training siamese network...

# %%
score_df2 = pd.DataFrame(scores_cv)

# %%
len(score_df2[3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-1a65bfcd38c8> in <module>
# ----> 1 len(score_df2[3])
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             self._check_indexing_error(key)
#     389             raise KeyError(key)
#
# KeyError: 3

# %%
for score_df in score_df2:
  print("next!")
  Acc_arr = score_df[0].tolist()
  bal_acc_arr = score_df[1].tolist()
  G_Mean_arr = score_df[2].tolist()
  F_Measure_arr = score_df[3].tolist()
  Precision_arr = score_df[4].tolist()
  Sensitivity_arr = score_df[5].tolist()
  Specificity_arr = score_df[6].tolist()
  Auc_arr = score_df[7].tolist()

  print('bal_acc_arr: mean=%.3f std=%.3f' % (np.mean(bal_acc_arr)*100, np.std(bal_acc_arr)*100))
  print('G_Mean_arr: mean=%.3f std=%.3f' % (np.mean(G_Mean_arr)*100, np.std(G_Mean_arr)*100))
  print('F_Measure_arr: mean=%.3f std=%.3f' % (np.mean(F_Measure_arr)*100, np.std(F_Measure_arr)*100))
  print('Auc_arr: mean=%.3f std=%.3f' % (np.mean(Auc_arr)*100, np.std(Auc_arr)*100))
  print('Precision_arr: mean=%.3f std=%.3f' % (np.mean(Precision_arr)*100, np.std(Precision_arr)*100))
  print('Sensitivity_arr: mean=%.3f std=%.3f' % (np.mean(Sensitivity_arr)*100, np.std(Sensitivity_arr)*100))
  print('Specificity_arr: mean=%.3f std=%.3f' % (np.mean(Specificity_arr)*100, np.std(Specificity_arr)*100))
  print('Acc_arr: mean=%.3f std=%.3f' % (np.mean(Acc_arr)*100, np.std(Acc_arr)*100))
# Out:
# next!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-426f216ddbcf> in <module>
#       1 for score_df in score_df2:
#       2   print("next!")
# ----> 3   Acc_arr = score_df[0].tolist()
#       4   bal_acc_arr = score_df[1].tolist()
#       5   G_Mean_arr = score_df[2].tolist()
#
# TypeError: 'int' object is not subscriptable

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
thresholds = [0.02, 0.05, 0.1, 0.3, 0.5]
ks = [3,5,7,9]
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

for k in ks:
  for threshold in thresholds:
    scores = []
    for i in range(3):
      for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
        # print(f"Fold {fold+1}")
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        sia_model = fu.train_siamese_dense(X_train, y_train, X_test, y_test, num_classes=2, num_features=num_features, epochs_siamese=100, batch_size=16)

        # Initialize the SVM classifier
        clf = svm.SVC()

        X_train_resampled, y_train_resampled = fu.sia_smote_then_smote_dense(X_train, y_train, sia_model, threshold, maxdist_from_base=0.5, k = k)

        # Train the classifier on the training set
        clf.fit(X_train_resampled, y_train_resampled)

        # Predict the labels of the test set
        y_pred = clf.predict(X_test)

        # Calculate the F1 score
        score = fu.calculate_score(y_test, y_pred)
        scores.append(score)

        # Print the F1 score
        print(f"Score in i:{i}, fold:{fold}:", score)

    print(f'k={k} and threshold={threshold}')
    print('printing score')
    fu.print_score(scores)
# Out:
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2484
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.24843288958072662, Train Accuracy = 0.7023809523809523 Test Accuracy = 0.5
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:0: [0.5483870967741935, 0.5973856209150327, 0.587450456818008, 0.46153846153846156, 0.34285714285714286, 0.7058823529411765, 0.4888888888888889, 0.5973856209150328]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2795
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.2795407176017761, Train Accuracy = 0.65234375 Test Accuracy = 0.6
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:1: [0.6721311475409836, 0.6368055555555556, 0.6324555320336759, 0.47368421052631576, 0.4090909090909091, 0.5625, 0.7111111111111111, 0.6368055555555556]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2362
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.23615793883800507, Train Accuracy = 0.671875 Test Accuracy = 0.5666666666666667
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:2: [0.6557377049180327, 0.6055555555555556, 0.5962847939999439, 0.4324324324324324, 0.38095238095238093, 0.5, 0.7111111111111111, 0.6055555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2869
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.28693872690200806, Train Accuracy = 0.71875 Test Accuracy = 0.4666666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:3: [0.6557377049180327, 0.6458333333333333, 0.6454972243679028, 0.48780487804878053, 0.4, 0.625, 0.6666666666666666, 0.6458333333333334]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3280
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.3280309736728668, Train Accuracy = 0.72265625 Test Accuracy = 0.43333333333333335
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:4: [0.6885245901639344, 0.5875, 0.5477225575051662, 0.38709677419354843, 0.4, 0.375, 0.8, 0.5875]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2469
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.24694116413593292, Train Accuracy = 0.6825396825396826 Test Accuracy = 0.65625
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:0: [0.5, 0.5274509803921569, 0.5239368319955838, 0.3921568627450981, 0.29411764705882354, 0.5882352941176471, 0.4666666666666667, 0.5274509803921569]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2692
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.2691921889781952, Train Accuracy = 0.65234375 Test Accuracy = 0.6
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:1: [0.6557377049180327, 0.6055555555555556, 0.5962847939999439, 0.4324324324324324, 0.38095238095238093, 0.5, 0.7111111111111111, 0.6055555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2462
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.24623723328113556, Train Accuracy = 0.6171875 Test Accuracy = 0.5666666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:2: [0.6229508196721312, 0.6034722222222222, 0.6020797289396148, 0.43902439024390244, 0.36, 0.5625, 0.6444444444444445, 0.6034722222222222]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2930
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.293008416891098, Train Accuracy = 0.71875 Test Accuracy = 0.48333333333333334
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:3: [0.6557377049180327, 0.6458333333333333, 0.6454972243679028, 0.48780487804878053, 0.4, 0.625, 0.6666666666666666, 0.6458333333333334]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3035
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.30346882343292236, Train Accuracy = 0.734375 Test Accuracy = 0.48333333333333334
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:4: [0.7213114754098361, 0.6701388888888888, 0.6614378277661477, 0.5142857142857142, 0.47368421052631576, 0.5625, 0.7777777777777778, 0.670138888888889]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2557
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.2556717097759247, Train Accuracy = 0.6825396825396826 Test Accuracy = 0.484375
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:0: [0.6129032258064516, 0.6418300653594771, 0.6386259760257971, 0.5, 0.3870967741935484, 0.7058823529411765, 0.5777777777777777, 0.6418300653594772]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2726
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.2725609838962555, Train Accuracy = 0.62890625 Test Accuracy = 0.6
# 4/4 [==============================] - 0s 4ms/step
# Score in i:2, fold:1: [0.5737704918032787, 0.55, 0.5477225575051661, 0.380952380952381, 0.3076923076923077, 0.5, 0.6, 0.5499999999999999]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2677
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.26767316460609436, Train Accuracy = 0.6875 Test Accuracy = 0.6166666666666667
# 4/4 [==============================] - 0s 5ms/step
# Score in i:2, fold:2: [0.6557377049180327, 0.525, 0.4472135954999579, 0.27586206896551724, 0.3076923076923077, 0.25, 0.8, 0.525]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2988
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.29879507422447205, Train Accuracy = 0.703125 Test Accuracy = 0.4666666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:3: [0.639344262295082, 0.6347222222222222, 0.6346477588219923, 0.4761904761904762, 0.38461538461538464, 0.625, 0.6444444444444445, 0.6347222222222222]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3235
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.32352516055107117, Train Accuracy = 0.6953125 Test Accuracy = 0.4666666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:4: [0.7213114754098361, 0.6701388888888888, 0.6614378277661477, 0.5142857142857142, 0.47368421052631576, 0.5625, 0.7777777777777778, 0.670138888888889]
# k=3 and threshold=0.02
# printing score
# bal_acc_arr: mean=60.981 std=4.512
# G_Mean_arr: mean=59.789 std=5.782
# F_Measure_arr: mean=44.370 std=6.194
# Auc_arr: mean=60.981 std=4.512
# Precision_arr: mean=38.016 std=5.118
# Sensitivity_arr: mean=55.000 std=11.422
# Specificity_arr: mean=66.963 std=10.033
# Acc_arr: mean=63.862 std=5.844
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2539
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.25390535593032837, Train Accuracy = 0.6388888888888888 Test Accuracy = 0.609375
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:0: [0.5645161290322581, 0.6084967320261438, 0.6006532391700641, 0.4705882352941177, 0.35294117647058826, 0.7058823529411765, 0.5111111111111111, 0.6084967320261438]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2851
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2850785553455353, Train Accuracy = 0.63671875 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:1: [0.6721311475409836, 0.5965277777777778, 0.5749396103553447, 0.411764705882353, 0.3888888888888889, 0.4375, 0.7555555555555555, 0.5965277777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2493
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.24931134283542633, Train Accuracy = 0.6796875 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:2: [0.5737704918032787, 0.5902777777777778, 0.5892556509887896, 0.43478260869565216, 0.3333333333333333, 0.625, 0.5555555555555556, 0.5902777777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2844
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.28442642092704773, Train Accuracy = 0.72265625 Test Accuracy = 0.5333333333333333
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:3: [0.639344262295082, 0.6548611111111111, 0.6540472290116195, 0.5, 0.39285714285714285, 0.6875, 0.6222222222222222, 0.6548611111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3223
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.32228314876556396, Train Accuracy = 0.70703125 Test Accuracy = 0.45
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:4: [0.7377049180327869, 0.6409722222222223, 0.6078194176270156, 0.4666666666666667, 0.5, 0.4375, 0.8444444444444444, 0.6409722222222222]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2477
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.24772560596466064, Train Accuracy = 0.6626984126984127 Test Accuracy = 0.5625
# 4/4 [==============================] - 0s 2ms/step
# Score in i:1, fold:0: [0.532258064516129, 0.5679738562091503, 0.562440991821405, 0.4313725490196078, 0.3235294117647059, 0.6470588235294118, 0.4888888888888889, 0.5679738562091503]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3020
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.30200812220573425, Train Accuracy = 0.67578125 Test Accuracy = 0.5
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:1: [0.7213114754098361, 0.6298611111111111, 0.5997684738482194, 0.45161290322580644, 0.4666666666666667, 0.4375, 0.8222222222222222, 0.6298611111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2510
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.25097981095314026, Train Accuracy = 0.66796875 Test Accuracy = 0.5666666666666667
# 4/4 [==============================] - 0s 5ms/step
# Score in i:1, fold:2: [0.6557377049180327, 0.6256944444444444, 0.6224949798994366, 0.46153846153846156, 0.391304347826087, 0.5625, 0.6888888888888889, 0.6256944444444444]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2884
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.2883639633655548, Train Accuracy = 0.72265625 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:3: [0.6721311475409836, 0.6166666666666667, 0.6055300708194983, 0.4444444444444445, 0.4, 0.5, 0.7333333333333333, 0.6166666666666667]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3040
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.3040231466293335, Train Accuracy = 0.7109375 Test Accuracy = 0.4
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:4: [0.7540983606557377, 0.6319444444444444, 0.5773502691896257, 0.4444444444444444, 0.5454545454545454, 0.375, 0.8888888888888888, 0.6319444444444444]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2387
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.238722026348114, Train Accuracy = 0.6825396825396826 Test Accuracy = 0.625
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:0: [0.5967741935483871, 0.630718954248366, 0.6262242910851495, 0.48979591836734687, 0.375, 0.7058823529411765, 0.5555555555555556, 0.630718954248366]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2706
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2706106901168823, Train Accuracy = 0.703125 Test Accuracy = 0.6166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:1: [0.6885245901639344, 0.6277777777777778, 0.6146362971528592, 0.45714285714285713, 0.42105263157894735, 0.5, 0.7555555555555555, 0.6277777777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2571
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.25713327527046204, Train Accuracy = 0.67578125 Test Accuracy = 0.5333333333333333
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:2: [0.5409836065573771, 0.5680555555555555, 0.565194165260439, 0.4166666666666667, 0.3125, 0.625, 0.5111111111111111, 0.5680555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3247
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.32470595836639404, Train Accuracy = 0.6796875 Test Accuracy = 0.4666666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:3: [0.6065573770491803, 0.5319444444444444, 0.5082650227325635, 0.33333333333333326, 0.3, 0.375, 0.6888888888888889, 0.5319444444444444]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2939
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2939179539680481, Train Accuracy = 0.70703125 Test Accuracy = 0.5
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:4: [0.7213114754098361, 0.6298611111111111, 0.5997684738482194, 0.45161290322580644, 0.4666666666666667, 0.4375, 0.8222222222222222, 0.6298611111111111]
# k=3 and threshold=0.05
# printing score
# bal_acc_arr: mean=61.011 std=3.211
# G_Mean_arr: mean=59.389 std=3.282
# F_Measure_arr: mean=44.438 std=3.771
# Auc_arr: mean=61.011 std=3.211
# Precision_arr: mean=39.801 std=6.903
# Sensitivity_arr: mean=53.725 std=11.627
# Specificity_arr: mean=68.296 std=12.995
# Acc_arr: mean=64.514 std=7.049
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2365
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.2365279197692871, Train Accuracy = 0.7182539682539683 Test Accuracy = 0.65625
# 4/4 [==============================] - 0s 5ms/step
# Score in i:0, fold:0: [0.532258064516129, 0.5679738562091503, 0.562440991821405, 0.4313725490196078, 0.3235294117647059, 0.6470588235294118, 0.4888888888888889, 0.5679738562091503]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2761
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.276146799325943, Train Accuracy = 0.640625 Test Accuracy = 0.5333333333333333
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:1: [0.7213114754098361, 0.6701388888888888, 0.6614378277661477, 0.5142857142857142, 0.47368421052631576, 0.5625, 0.7777777777777778, 0.670138888888889]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2584
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.2584255039691925, Train Accuracy = 0.67578125 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:2: [0.6229508196721312, 0.5631944444444444, 0.5489889697333534, 0.37837837837837834, 0.3333333333333333, 0.4375, 0.6888888888888889, 0.5631944444444444]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2812
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2812422513961792, Train Accuracy = 0.68359375 Test Accuracy = 0.5666666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:3: [0.6557377049180327, 0.6055555555555556, 0.5962847939999439, 0.4324324324324324, 0.38095238095238093, 0.5, 0.7111111111111111, 0.6055555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3205
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.32050907611846924, Train Accuracy = 0.69140625 Test Accuracy = 0.45
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:4: [0.8032786885245902, 0.7256944444444444, 0.7071067811865476, 0.6000000000000001, 0.6428571428571429, 0.5625, 0.8888888888888888, 0.7256944444444444]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2478
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.24778079986572266, Train Accuracy = 0.6468253968253969 Test Accuracy = 0.515625
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:0: [0.5806451612903226, 0.5830065359477123, 0.5829830881301374, 0.4347826086956522, 0.3448275862068966, 0.5882352941176471, 0.5777777777777777, 0.5830065359477123]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2762
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2761695086956024, Train Accuracy = 0.6875 Test Accuracy = 0.6166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:1: [0.6721311475409836, 0.5965277777777778, 0.5749396103553447, 0.411764705882353, 0.3888888888888889, 0.4375, 0.7555555555555555, 0.5965277777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2785
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.27851638197898865, Train Accuracy = 0.67578125 Test Accuracy = 0.55
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:2: [0.6557377049180327, 0.6055555555555556, 0.5962847939999439, 0.4324324324324324, 0.38095238095238093, 0.5, 0.7111111111111111, 0.6055555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2842
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.28418076038360596, Train Accuracy = 0.703125 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:3: [0.639344262295082, 0.6145833333333333, 0.6123724356957945, 0.45, 0.375, 0.5625, 0.6666666666666666, 0.6145833333333334]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3525
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.35245898365974426, Train Accuracy = 0.6953125 Test Accuracy = 0.4166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:4: [0.7540983606557377, 0.6520833333333333, 0.6157651067303722, 0.4827586206896552, 0.5384615384615384, 0.4375, 0.8666666666666667, 0.6520833333333333]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2519
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2519106864929199, Train Accuracy = 0.7103174603174603 Test Accuracy = 0.65625
# 4/4 [==============================] - 0s 4ms/step
# Score in i:2, fold:0: [0.6129032258064516, 0.6418300653594771, 0.6386259760257971, 0.5, 0.3870967741935484, 0.7058823529411765, 0.5777777777777777, 0.6418300653594772]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2599
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 9ms/step
# compute val acc
# Loss = 0.25985461473464966, Train Accuracy = 0.66796875 Test Accuracy = 0.6166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:1: [0.6885245901639344, 0.6277777777777778, 0.6146362971528592, 0.45714285714285713, 0.42105263157894735, 0.5, 0.7555555555555555, 0.6277777777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2559
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.25585779547691345, Train Accuracy = 0.6875 Test Accuracy = 0.5333333333333333
# 4/4 [==============================] - 0s 4ms/step
# Score in i:2, fold:2: [0.639344262295082, 0.6548611111111111, 0.6540472290116195, 0.5, 0.39285714285714285, 0.6875, 0.6222222222222222, 0.6548611111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2906
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.29055944085121155, Train Accuracy = 0.7109375 Test Accuracy = 0.5333333333333333
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:3: [0.6065573770491803, 0.5118055555555556, 0.4714045207910317, 0.29411764705882354, 0.2777777777777778, 0.3125, 0.7111111111111111, 0.5118055555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3193
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.3192621171474457, Train Accuracy = 0.68359375 Test Accuracy = 0.4166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:4: [0.7540983606557377, 0.6520833333333333, 0.6157651067303722, 0.4827586206896552, 0.5384615384615384, 0.4375, 0.8666666666666667, 0.6520833333333333]
# k=3 and threshold=0.1
# printing score
# bal_acc_arr: mean=61.818 std=4.997
# G_Mean_arr: mean=60.354 std=5.281
# F_Measure_arr: mean=45.348 std=6.620
# Auc_arr: mean=61.818 std=4.997
# Precision_arr: mean=41.332 std=9.327
# Sensitivity_arr: mean=52.525 std=10.325
# Specificity_arr: mean=71.111 std=11.067
# Acc_arr: mean=66.259 std=6.967
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2428
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.24279123544692993, Train Accuracy = 0.6865079365079365 Test Accuracy = 0.59375
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:0: [0.532258064516129, 0.5862745098039216, 0.5739440431835515, 0.45283018867924524, 0.3333333333333333, 0.7058823529411765, 0.4666666666666667, 0.5862745098039216]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2738
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.27378401160240173, Train Accuracy = 0.625 Test Accuracy = 0.55
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:1: [0.6885245901639344, 0.6277777777777778, 0.6146362971528592, 0.45714285714285713, 0.42105263157894735, 0.5, 0.7555555555555555, 0.6277777777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2544
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.25437816977500916, Train Accuracy = 0.6796875 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:2: [0.6557377049180327, 0.6055555555555556, 0.5962847939999439, 0.4324324324324324, 0.38095238095238093, 0.5, 0.7111111111111111, 0.6055555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2839
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.28387895226478577, Train Accuracy = 0.70703125 Test Accuracy = 0.4666666666666667
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:3: [0.6065573770491803, 0.5118055555555556, 0.4714045207910317, 0.29411764705882354, 0.2777777777777778, 0.3125, 0.7111111111111111, 0.5118055555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3179
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.31789007782936096, Train Accuracy = 0.71875 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:4: [0.7377049180327869, 0.6409722222222223, 0.6078194176270156, 0.4666666666666667, 0.5, 0.4375, 0.8444444444444444, 0.6409722222222222]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2402
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.24022401869297028, Train Accuracy = 0.6944444444444444 Test Accuracy = 0.65625
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:0: [0.5967741935483871, 0.630718954248366, 0.6262242910851495, 0.48979591836734687, 0.375, 0.7058823529411765, 0.5555555555555556, 0.630718954248366]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2672
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 9ms/step
# compute val acc
# Loss = 0.2672262489795685, Train Accuracy = 0.68359375 Test Accuracy = 0.6333333333333333
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:1: [0.7540983606557377, 0.6722222222222223, 0.6497862896539309, 0.5161290322580646, 0.5333333333333333, 0.5, 0.8444444444444444, 0.6722222222222222]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2552
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.25520190596580505, Train Accuracy = 0.6328125 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:2: [0.6065573770491803, 0.5118055555555556, 0.4714045207910317, 0.29411764705882354, 0.2777777777777778, 0.3125, 0.7111111111111111, 0.5118055555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3066
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.3065950572490692, Train Accuracy = 0.67578125 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:3: [0.6557377049180327, 0.5652777777777778, 0.5322906474223771, 0.3636363636363636, 0.35294117647058826, 0.375, 0.7555555555555555, 0.5652777777777777]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3255
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.3255404531955719, Train Accuracy = 0.73046875 Test Accuracy = 0.45
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:4: [0.7540983606557377, 0.6118055555555555, 0.5335936864527374, 0.39999999999999997, 0.5555555555555556, 0.3125, 0.9111111111111111, 0.6118055555555555]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2597
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 10ms/step
# compute val acc
# Loss = 0.25965040922164917, Train Accuracy = 0.7023809523809523 Test Accuracy = 0.5625
# 4/4 [==============================] - 0s 4ms/step
# Score in i:2, fold:0: [0.532258064516129, 0.5496732026143791, 0.5483188805533162, 0.40816326530612246, 0.3125, 0.5882352941176471, 0.5111111111111111, 0.5496732026143791]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2834
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 9ms/step
# compute val acc
# Loss = 0.28342851996421814, Train Accuracy = 0.66796875 Test Accuracy = 0.5333333333333333
# 4/4 [==============================] - 0s 5ms/step
# Score in i:2, fold:1: [0.7377049180327869, 0.6611111111111111, 0.6411794687223782, 0.5, 0.5, 0.5, 0.8222222222222222, 0.6611111111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2729
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.27291029691696167, Train Accuracy = 0.71484375 Test Accuracy = 0.48333333333333334
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:2: [0.6557377049180327, 0.6256944444444444, 0.6224949798994366, 0.46153846153846156, 0.391304347826087, 0.5625, 0.6888888888888889, 0.6256944444444444]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3066
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.3066352307796478, Train Accuracy = 0.7109375 Test Accuracy = 0.5
# 4/4 [==============================] - 0s 4ms/step
# Score in i:2, fold:3: [0.6557377049180327, 0.5652777777777778, 0.5322906474223771, 0.3636363636363636, 0.35294117647058826, 0.375, 0.7555555555555555, 0.5652777777777777]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3222
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 10ms/step
# compute val acc
# Loss = 0.3221765160560608, Train Accuracy = 0.734375 Test Accuracy = 0.48333333333333334
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:4: [0.6885245901639344, 0.6277777777777778, 0.6146362971528592, 0.45714285714285713, 0.42105263157894735, 0.5, 0.7555555555555555, 0.6277777777777778]
# k=3 and threshold=0.3
# printing score
# bal_acc_arr: mean=59.958 std=4.805
# G_Mean_arr: mean=57.575 std=5.601
# F_Measure_arr: mean=42.382 std=6.672
# Auc_arr: mean=59.958 std=4.805
# Precision_arr: mean=39.903 std=8.576
# Sensitivity_arr: mean=47.917 std=12.398
# Specificity_arr: mean=72.000 std=12.085
# Acc_arr: mean=65.720 std=7.010
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2777
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 9ms/step
# compute val acc
# Loss = 0.2776957154273987, Train Accuracy = 0.626984126984127 Test Accuracy = 0.546875
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:0: [0.5483870967741935, 0.5973856209150327, 0.587450456818008, 0.46153846153846156, 0.34285714285714286, 0.7058823529411765, 0.4888888888888889, 0.5973856209150328]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2705
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2705451548099518, Train Accuracy = 0.625 Test Accuracy = 0.5
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:1: [0.6557377049180327, 0.6055555555555556, 0.5962847939999439, 0.4324324324324324, 0.38095238095238093, 0.5, 0.7111111111111111, 0.6055555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2512
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 10ms/step
# compute val acc
# Loss = 0.2511659860610962, Train Accuracy = 0.6875 Test Accuracy = 0.5833333333333334
# 4/4 [==============================] - 0s 5ms/step
# Score in i:0, fold:2: [0.6229508196721312, 0.6236111111111111, 0.6236095644623235, 0.4651162790697674, 0.37037037037037035, 0.625, 0.6222222222222222, 0.6236111111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2756
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.2756238281726837, Train Accuracy = 0.7421875 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 5ms/step
# Score in i:0, fold:3: [0.6229508196721312, 0.5229166666666667, 0.47871355387816905, 0.30303030303030304, 0.29411764705882354, 0.3125, 0.7333333333333333, 0.5229166666666667]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3137
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.31371888518333435, Train Accuracy = 0.734375 Test Accuracy = 0.5833333333333334
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:4: [0.7377049180327869, 0.7013888888888888, 0.6972166887783963, 0.5555555555555556, 0.5, 0.625, 0.7777777777777778, 0.7013888888888888]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2433
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.24329818785190582, Train Accuracy = 0.6587301587301587 Test Accuracy = 0.59375
# 4/4 [==============================] - 0s 5ms/step
# Score in i:1, fold:0: [0.5483870967741935, 0.5790849673202614, 0.5750816935430705, 0.44, 0.3333333333333333, 0.6470588235294118, 0.5111111111111111, 0.5790849673202614]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2725
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 9ms/step
# compute val acc
# Loss = 0.2725014388561249, Train Accuracy = 0.64453125 Test Accuracy = 0.5666666666666667
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:1: [0.6721311475409836, 0.5965277777777778, 0.5749396103553447, 0.411764705882353, 0.3888888888888889, 0.4375, 0.7555555555555555, 0.5965277777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2520
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 10ms/step
# compute val acc
# Loss = 0.2519962787628174, Train Accuracy = 0.6484375 Test Accuracy = 0.5833333333333334
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:2: [0.6557377049180327, 0.6256944444444444, 0.6224949798994366, 0.46153846153846156, 0.391304347826087, 0.5625, 0.6888888888888889, 0.6256944444444444]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2805
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 11ms/step
# compute val acc
# Loss = 0.2804522216320038, Train Accuracy = 0.671875 Test Accuracy = 0.5
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:3: [0.6721311475409836, 0.6166666666666667, 0.6055300708194983, 0.4444444444444445, 0.4, 0.5, 0.7333333333333333, 0.6166666666666667]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3217
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.3216864764690399, Train Accuracy = 0.73046875 Test Accuracy = 0.4
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:4: [0.7377049180327869, 0.6208333333333333, 0.570087712549569, 0.42857142857142855, 0.5, 0.375, 0.8666666666666667, 0.6208333333333333]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2409
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.24091747403144836, Train Accuracy = 0.6944444444444444 Test Accuracy = 0.625
# 4/4 [==============================] - 0s 4ms/step
# ...
# Score in i:1, fold:1: [0.7213114754098361, 0.6298611111111111, 0.5997684738482194, 0.45161290322580644, 0.4666666666666667, 0.4375, 0.8222222222222222, 0.6298611111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2541
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 7ms/step
# compute val acc
# Loss = 0.2540737986564636, Train Accuracy = 0.640625 Test Accuracy = 0.55
# 4/4 [==============================] - 0s 6ms/step
# Score in i:1, fold:2: [0.639344262295082, 0.5743055555555556, 0.5577733510227171, 0.38888888888888884, 0.35, 0.4375, 0.7111111111111111, 0.5743055555555556]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2885
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.28845271468162537, Train Accuracy = 0.72265625 Test Accuracy = 0.48333333333333334
# 4/4 [==============================] - 0s 5ms/step
# Score in i:1, fold:3: [0.6229508196721312, 0.5430555555555556, 0.5163977794943222, 0.34285714285714286, 0.3157894736842105, 0.375, 0.7111111111111111, 0.5430555555555556]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2985
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 12ms/step
# compute val acc
# Loss = 0.29846036434173584, Train Accuracy = 0.70703125 Test Accuracy = 0.48333333333333334
# 4/4 [==============================] - 0s 4ms/step
# Score in i:1, fold:4: [0.7377049180327869, 0.6611111111111111, 0.6411794687223782, 0.5, 0.5, 0.5, 0.8222222222222222, 0.6611111111111111]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2643
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.26433712244033813, Train Accuracy = 0.6984126984126984 Test Accuracy = 0.515625
# 4/4 [==============================] - 0s 3ms/step
# Score in i:2, fold:0: [0.5645161290322581, 0.6084967320261438, 0.6006532391700641, 0.4705882352941177, 0.35294117647058826, 0.7058823529411765, 0.5111111111111111, 0.6084967320261438]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 19ms/step - loss: 0.2902
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 16ms/step
# compute val acc
# Loss = 0.2901883125305176, Train Accuracy = 0.68359375 Test Accuracy = 0.5833333333333334
# 4/4 [==============================] - 0s 6ms/step
# Score in i:2, fold:1: [0.7213114754098361, 0.6298611111111111, 0.5997684738482194, 0.45161290322580644, 0.4666666666666667, 0.4375, 0.8222222222222222, 0.6298611111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2446
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 9ms/step
# compute val acc
# Loss = 0.24459566175937653, Train Accuracy = 0.66015625 Test Accuracy = 0.5666666666666667
# 4/4 [==============================] - 0s 8ms/step
# Score in i:2, fold:2: [0.639344262295082, 0.6145833333333333, 0.6123724356957945, 0.45, 0.375, 0.5625, 0.6666666666666666, 0.6145833333333334]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2747
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.27466896176338196, Train Accuracy = 0.703125 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 4ms/step
# Score in i:2, fold:3: [0.6885245901639344, 0.6277777777777778, 0.6146362971528592, 0.45714285714285713, 0.42105263157894735, 0.5, 0.7555555555555555, 0.6277777777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 14ms/step - loss: 0.3154
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.31541621685028076, Train Accuracy = 0.7421875 Test Accuracy = 0.4
# 4/4 [==============================] - 0s 8ms/step
# Score in i:2, fold:4: [0.7868852459016393, 0.7145833333333333, 0.6982120021884471, 0.5806451612903225, 0.6, 0.5625, 0.8666666666666667, 0.7145833333333333]
# k=9 and threshold=0.3
# printing score
# bal_acc_arr: mean=61.066 std=4.838
# G_Mean_arr: mean=58.901 std=5.649
# F_Measure_arr: mean=43.889 std=6.848
# Auc_arr: mean=61.066 std=4.838
# Precision_arr: mean=41.606 std=9.338
# Sensitivity_arr: mean=48.799 std=10.859
# Specificity_arr: mean=73.333 std=11.418
# Acc_arr: mean=66.919 std=6.978
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2344
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.23443135619163513, Train Accuracy = 0.6666666666666666 Test Accuracy = 0.640625
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:0: [0.5967741935483871, 0.630718954248366, 0.6262242910851495, 0.48979591836734687, 0.375, 0.7058823529411765, 0.5555555555555556, 0.630718954248366]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2802
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.28017526865005493, Train Accuracy = 0.64453125 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 3ms/step
# Score in i:0, fold:1: [0.6721311475409836, 0.5965277777777778, 0.5749396103553447, 0.411764705882353, 0.3888888888888889, 0.4375, 0.7555555555555555, 0.5965277777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2699
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.2699376940727234, Train Accuracy = 0.703125 Test Accuracy = 0.5333333333333333
# 4/4 [==============================] - 0s 6ms/step
# Score in i:0, fold:2: [0.639344262295082, 0.49375, 0.3872983346207417, 0.21428571428571427, 0.25, 0.1875, 0.8, 0.49375]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3008
# predict train
# 8/8 [==============================] - 0s 5ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.30077847838401794, Train Accuracy = 0.71484375 Test Accuracy = 0.5
# 4/4 [==============================] - 0s 4ms/step
# Score in i:0, fold:3: [0.6557377049180327, 0.6055555555555556, 0.5962847939999439, 0.4324324324324324, 0.38095238095238093, 0.5, 0.7111111111111111, 0.6055555555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3187
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 11ms/step
# compute val acc
# Loss = 0.31871330738067627, Train Accuracy = 0.7109375 Test Accuracy = 0.4666666666666667
# 4/4 [==============================] - 0s 5ms/step
# Score in i:0, fold:4: [0.7540983606557377, 0.6722222222222223, 0.6497862896539309, 0.5161290322580646, 0.5333333333333333, 0.5, 0.8444444444444444, 0.6722222222222222]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2532
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.2531754970550537, Train Accuracy = 0.6984126984126984 Test Accuracy = 0.578125
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:0: [0.5967741935483871, 0.5941176470588235, 0.5940885257860046, 0.4444444444444445, 0.35714285714285715, 0.5882352941176471, 0.6, 0.5941176470588235]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2990
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.29902413487434387, Train Accuracy = 0.61328125 Test Accuracy = 0.48333333333333334
# 4/4 [==============================] - 0s 3ms/step
# Score in i:1, fold:1: [0.6557377049180327, 0.5854166666666667, 0.5664215155988809, 0.39999999999999997, 0.3684210526315789, 0.4375, 0.7333333333333333, 0.5854166666666667]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 14ms/step - loss: 0.2468
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 5ms/step
# compute val acc
# Loss = 0.24679794907569885, Train Accuracy = 0.671875 Test Accuracy = 0.5833333333333334
# 4/4 [==============================] - 0s 5ms/step
# Score in i:1, fold:2: [0.6065573770491803, 0.5923611111111111, 0.5916079783099616, 0.4285714285714286, 0.34615384615384615, 0.5625, 0.6222222222222222, 0.5923611111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3063
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 11ms/step
# compute val acc
# Loss = 0.3062795400619507, Train Accuracy = 0.6875 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 5ms/step
# Score in i:1, fold:3: [0.6065573770491803, 0.5319444444444444, 0.5082650227325635, 0.33333333333333326, 0.3, 0.375, 0.6888888888888889, 0.5319444444444444]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3239
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 4ms/step
# compute val acc
# Loss = 0.3238893449306488, Train Accuracy = 0.6796875 Test Accuracy = 0.4
# 4/4 [==============================] - 0s 7ms/step
# Score in i:1, fold:4: [0.7704918032786885, 0.6833333333333333, 0.6582805886043833, 0.5333333333333333, 0.5714285714285714, 0.5, 0.8666666666666667, 0.6833333333333333]
# creating pairs
# Counter({1.0: 126, 0.0: 126})
# Counter({1.0: 32, 0.0: 32})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2312
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 10ms/step
# compute val acc
# Loss = 0.23117725551128387, Train Accuracy = 0.7182539682539683 Test Accuracy = 0.671875
# 4/4 [==============================] - 0s 5ms/step
# Score in i:2, fold:0: [0.5483870967741935, 0.5241830065359476, 0.5214359259166952, 0.3636363636363636, 0.2962962962962963, 0.47058823529411764, 0.5777777777777777, 0.5241830065359477]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2724
# predict train
# 8/8 [==============================] - 0s 3ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.27241721749305725, Train Accuracy = 0.67578125 Test Accuracy = 0.6
# 4/4 [==============================] - 0s 5ms/step
# Score in i:2, fold:1: [0.6065573770491803, 0.5923611111111111, 0.5916079783099616, 0.4285714285714286, 0.34615384615384615, 0.5625, 0.6222222222222222, 0.5923611111111111]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 13ms/step - loss: 0.2427
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 3ms/step
# compute val acc
# Loss = 0.24270254373550415, Train Accuracy = 0.67578125 Test Accuracy = 0.5833333333333334
# 4/4 [==============================] - 0s 7ms/step
# Score in i:2, fold:2: [0.5573770491803278, 0.5590277777777778, 0.5590169943749475, 0.4, 0.3103448275862069, 0.5625, 0.5555555555555556, 0.5590277777777778]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2862
# predict train
# 8/8 [==============================] - 0s 4ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 8ms/step
# compute val acc
# Loss = 0.28619542717933655, Train Accuracy = 0.703125 Test Accuracy = 0.5166666666666667
# 4/4 [==============================] - 0s 4ms/step
# Score in i:2, fold:3: [0.6065573770491803, 0.5118055555555556, 0.4714045207910317, 0.29411764705882354, 0.2777777777777778, 0.3125, 0.7111111111111111, 0.5118055555555555]
# creating pairs
# Counter({1.0: 128, 0.0: 128})
# Counter({1.0: 30, 0.0: 30})
# init base network
# training siamese network...
# evaluate
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3221
# predict train
# 8/8 [==============================] - 0s 2ms/step
# compute train acc
# predict val
# 2/2 [==============================] - 0s 6ms/step
# compute val acc
# Loss = 0.3221379220485687, Train Accuracy = 0.73046875 Test Accuracy = 0.43333333333333335
# 4/4 [==============================] - 0s 5ms/step
# Score in i:2, fold:4: [0.7540983606557377, 0.6923611111111111, 0.6800735254367721, 0.5454545454545455, 0.5294117647058824, 0.5625, 0.8222222222222222, 0.6923611111111111]
# k=9 and threshold=0.5
# printing score
# bal_acc_arr: mean=59.105 std=5.886
# G_Mean_arr: mean=57.178 std=7.349
# F_Measure_arr: mean=41.572 std=8.681
# Auc_arr: mean=59.105 std=5.886
# Precision_arr: mean=37.542 std=9.339
# Sensitivity_arr: mean=48.431 std=12.089
# Specificity_arr: mean=69.778 std=10.225
# Acc_arr: mean=64.181 std=6.732
